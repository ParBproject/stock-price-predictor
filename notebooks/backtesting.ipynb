# %% [markdown]
# # Backtesting with Backtrader
#
# ## What is Backtesting?
# Backtesting simulates how a trading strategy would have performed on *historical* data.
# It is essential for evaluating whether model predictions are actually actionable.
#
# ## Strategy Logic
# - **Signal**: If the model predicts tomorrow's Close > today's Close → **BUY**
# - **Exit**:   If the model predicts tomorrow's Close < today's Close → **SELL**
# - We compare against a simple **Buy & Hold** benchmark.
#
# ## Forecast alignment
# Predictions are generated from feature row **t** for target **t+1**, using the same
# shifted 80/20 sample boundary as the Random Forest training notebook. Signals are
# attached to row **t**, so Backtrader can place the order for the next bar without
# using future price information.
#
# ## Benchmark alignment
# Buy & Hold starts at the same first executable next-bar open and pays the same entry
# commission, so the comparison does not credit the benchmark with an untradeable gap.
#
# ## Artifact safety
# Loaded Random Forest models must carry the same feature names in the same order as
# the current pipeline; legacy or stale artifacts are rejected before inference.
#
# ## Caveats
# - This is for **educational purposes only**.
# - Real trading incurs slippage, transaction costs, and market impact.
# - Past performance does not guarantee future results.

# %%
import sys; sys.path.insert(0, '..')
import warnings; warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import backtrader as bt
import joblib

from src.data_loader import fetch_stock_data, prepare_forecast_data
from src.backtesting import (
    buy_and_hold_equity_values, commission_aware_position_size, is_terminal_order,
    next_day_direction_signals, portfolio_value_series,
)
from src.model_artifacts import validate_sklearn_feature_schema
from src.sentiment_analyzer import add_sentiment_to_df
from src.evaluator import sharpe_ratio, max_drawdown, plot_equity_curve

# %matplotlib inline
plt.style.use('seaborn-v0_8-darkgrid')
print('Setup complete')
# Out:
# Setup complete

# %%
# ── Config ────────────────────────────────────────────────────────────────────
TICKER                  = 'AAPL'
START                   = '2015-01-01'
END                     = '2024-12-31'
TRAIN_RATIO             = 0.80
INITIAL_CASH            = 10_000.0
COMMISSION_RATE         = 0.001       # 0.1 % per trade
ANNUAL_RISK_FREE_RATE   = 0.04        # 4 % annual risk-free rate

FEATURE_COLS = [
    'Open', 'High', 'Low', 'Volume',
    'SMA_10', 'SMA_20', 'SMA_50',
    'RSI_14', 'RSI_7', 'MACD', 'MACD_Signal', 'MACD_Hist',
    'BB_Width', 'ATR_14', 'Vol_Change', 'OBV',
    'Log_Return', 'Pct_Change', 'Sentiment',
    'Close_Lag_1', 'Close_Lag_2', 'Close_Lag_3',
    'Close_Lag_5', 'Close_Lag_10',
]

# %%
# ── 1. Load data & generate next-day predictions ─────────────────────────────
df = fetch_stock_data(TICKER, START, END)
df = add_sentiment_to_df(df, TICKER, START, END)
feature_cols = [c for c in FEATURE_COLS if c in df.columns]

# Recreate the exact supervised sample set used by random_forest_model.ipynb.
X, _, target_dates = prepare_forecast_data(
    df, feature_cols, target_col='Close', horizon=1
)
split = int(len(X) * TRAIN_RATIO)
X_test = X.iloc[split:]
target_dates = target_dates[split:]

if X_test.empty:
    raise ValueError('No holdout rows available for backtesting')

# At feature date t, Close[t] is known and the model forecasts Close[t+1].
current_close = df.loc[X_test.index, 'Close'].to_numpy()

# Load trained RF regressor (run random_forest_model.ipynb first).
try:
    rf = joblib.load('../results/rf_regressor.pkl')
    validate_sklearn_feature_schema(rf, X_test.columns)
    preds = rf.predict(X_test)
    print('Loaded schema-compatible RF regressor predictions')
except FileNotFoundError:
    # Persistence baseline: tomorrow's close is forecast as today's close.
    print('RF model not found – using current-close persistence fallback')
    preds = current_close.copy()

signals = next_day_direction_signals(preds, current_close)

# Include the final target bar so an order placed on the last feature bar can
# execute on the next bar. That terminal bar intentionally has no new signal.
test_df = df.loc[X_test.index[0]:target_dates[-1]].copy()
test_df['Pred_Close'] = np.nan
test_df['Signal'] = -1
test_df.loc[X_test.index, 'Pred_Close'] = preds
test_df.loc[X_test.index, 'Signal'] = signals

print(
    f'Backtest feature window: {X_test.index[0].date()} -> {X_test.index[-1].date()} | '
    f'final target: {target_dates[-1].date()}'
)
# Out:
# [DataLoader] Fetching AAPL from 2015-01-01 to 2024-12-31 ...
# [DataLoader] Raw shape: (2515, 5)
# [ADF] Close (raw): stat=0.8448, p=0.9923 → NON-STATIONARY
# [ADF] Close (1st diff): stat=-16.1787, p=0.0 → STATIONARY
# [DataLoader] Shape after feature engineering & dropna: (2466, 31)
# [Sentiment] NEWS_API_KEY not set – returning empty list.
# [Sentiment] No headline data – using neutral sentiment fallback.
# Loaded schema-compatible RF regressor predictions
# Backtest feature window: 2023-01-12 -> 2024-12-27 | final target: 2024-12-30

# %%
# ── 2. Build Backtrader DataFeed ──────────────────────────────────────────────
# Backtrader expects a pandas dataframe with a specific column schema.

bt_data = test_df[['Open', 'High', 'Low', 'Close', 'Volume']].copy()
bt_data.index = pd.to_datetime(bt_data.index)
bt_data.columns = ['open', 'high', 'low', 'close', 'volume']

data_feed = bt.feeds.PandasData(dataname=bt_data)

# %%
# ── 3. Define Trading Strategy ────────────────────────────────────────────────

class MLSignalStrategy(bt.Strategy):
    """
    Trades based on an externally computed signal array.
    Signal = 1  → BUY all-in (commission-aware)
    Signal = 0  → SELL (exit position)
    Signal = -1 → HOLD / no new order
    """
    params = dict(signals=None, printlog=False, commission_rate=0.0)

    def log(self, txt, dt=None):
        if self.params.printlog:
            dt = dt or self.datas[0].datetime.date(0)
            print(f'{dt} {txt}')

    def __init__(self):
        self.idx      = 0
        self.signals  = self.params.signals
        self.order    = None
        self.portfolio_values = []

    def next(self):
        # Exactly one marked-to-market observation per data bar.
        self.portfolio_values.append(self.broker.getvalue())

        if self.order:
            return   # wait for pending order

        signal = self.signals[self.idx] if self.idx < len(self.signals) else -1
        self.idx += 1

        if signal == 1 and not self.position:
            cash = self.broker.getcash()
            size = commission_aware_position_size(
                cash, self.data.close[0], self.params.commission_rate
            )
            if size > 0:
                self.order = self.buy(size=size)
                self.log(f'BUY  @{self.data.close[0]:.2f} x{size}')

        elif signal == 0 and self.position:
            self.order = self.sell(size=self.position.size)
            self.log(f'SELL @{self.data.close[0]:.2f}')

    def notify_order(self, order):
        if is_terminal_order(order):
            self.order = None

    def stop(self):
        # The final bar was already recorded by next(); do not append N+1.
        self.log(f'Final portfolio value: {self.broker.getvalue():.2f}')

# %%
# ── 4. Run Backtest ───────────────────────────────────────────────────────────
signals_arr = test_df['Signal'].to_numpy(dtype=int)

cerebro = bt.Cerebro()
cerebro.adddata(data_feed)
cerebro.addstrategy(
    MLSignalStrategy,
    signals=signals_arr,
    printlog=True,
    commission_rate=COMMISSION_RATE,
)
cerebro.broker.setcash(INITIAL_CASH)
cerebro.broker.setcommission(commission=COMMISSION_RATE)

# Backtrader expects an annual risk-free rate and converts it to the chosen
# timeframe internally; annualize the daily Sharpe for comparison with our helper.
cerebro.addanalyzer(
    bt.analyzers.SharpeRatio,
    _name='sharpe',
    timeframe=bt.TimeFrame.Days,
    riskfreerate=ANNUAL_RISK_FREE_RATE,
    annualize=True,
)
cerebro.addanalyzer(bt.analyzers.DrawDown,   _name='drawdown')
cerebro.addanalyzer(bt.analyzers.Returns,    _name='returns')

print(f'Starting Portfolio Value: ${cerebro.broker.getvalue():,.2f}')
results = cerebro.run()
strat   = results[0]
final_val = cerebro.broker.getvalue()
print(f'Ending Portfolio Value:   ${final_val:,.2f}')
print(f'Total Return:             {(final_val/INITIAL_CASH - 1)*100:.2f}%')
# Out:
# Starting Portfolio Value: $10,000.00
# 2023-01-17 BUY  @133.56 x74
# 2023-01-24 SELL @140.03
# 2023-01-26 BUY  @141.44 x72
# 2023-02-02 SELL @148.18
# 2023-02-09 BUY  @148.22 x71
# 2023-02-14 SELL @150.74
# 2023-02-17 BUY  @150.10 x72
# 2023-02-22 SELL @146.52
# 2023-02-27 BUY  @145.55 x74
# 2023-03-01 SELL @142.98
# 2023-03-06 BUY  @151.36 x69
# 2023-03-07 SELL @149.17
# 2023-03-09 BUY  @148.18 x70
# 2023-03-14 SELL @150.14
# 2023-03-17 BUY  @152.51 x69
# 2023-04-04 SELL @162.97
# 2023-04-05 BUY  @161.13 x69
# 2023-04-10 SELL @159.43
# 2023-04-12 BUY  @157.53 x70
# 2023-04-13 SELL @162.91
# 2023-04-17 BUY  @162.58 x69
# 2023-04-21 SELL @162.37
# 2023-04-24 BUY  @162.68 x69
# 2023-04-27 SELL @165.71
# 2023-05-02 BUY  @165.84 x68
# 2023-05-04 SELL @163.13
# 2023-05-12 BUY  @170.04 x67
# 2023-05-16 SELL @169.54
# 2023-10-26 BUY  @164.66 x69
# 2023-10-27 SELL @165.98
# 2024-03-15 BUY  @170.76 x67
# 2024-04-22 BUY  @164.05 x70
# 2024-04-23 SELL @165.10
# 2024-04-30 BUY  @168.49 x68
# ...

# %%
# ── 5. Analyser Results ───────────────────────────────────────────────────────
sharpe_bt = strat.analyzers.sharpe.get_analysis()
dd_bt     = strat.analyzers.drawdown.get_analysis()
print(f"Sharpe Ratio (bt):  {sharpe_bt.get('sharperatio', 'N/A')}")
print(f"Max Drawdown:       {dd_bt.max.drawdown:.2f}%")
# Out:
# Sharpe Ratio (bt):  0.9413254207871112
# Max Drawdown:       4.74%

# %%
# ── 6. Plot Equity Curve vs Buy & Hold ────────────────────────────────────────
portfolio_vals = portfolio_value_series(
    strat.portfolio_values, test_df.index
)

# Buy & Hold uses the same first executable next-open timing and entry fee.
bh_values = buy_and_hold_equity_values(
    test_df['Open'].to_numpy(dtype=float),
    test_df['Close'].to_numpy(dtype=float),
    initial_cash=INITIAL_CASH,
    commission_rate=COMMISSION_RATE,
    entry_index=1,
)
bh = portfolio_value_series(
    bh_values, test_df.index, name='Buy & Hold'
)

plot_equity_curve(portfolio_vals, label='ML Strategy', benchmark=bh)
# Out:
# [Evaluator] Saved → /agent/repos/stock-price-predictor/notebooks/../src/../results/ml_strategy_equity.png

# %%
# ── 7. Plot Backtrader Chart ──────────────────────────────────────────────────
# Note: backtrader's built-in plot requires matplotlib backend
cerebro.plot(style='candlestick', iplot=False)
# Out:
# [[<Figure size 640x480 with 4 Axes>]]
