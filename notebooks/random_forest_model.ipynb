# %% [markdown]
# # Random Forest Model – Stock Price Prediction
#
# ## Why Random Forest as Baseline?
# Random Forests aggregate hundreds of decision trees, each trained on a random
# sub-sample of data and features. The ensemble majority vote (classifier) or
# average (regressor) reduces variance substantially, making it robust and
# interpretable via **feature importances**.
#
# Unlike LSTM, it doesn't natively understand temporal ordering, so we engineer
# lagged features and rolling statistics explicitly.
#
# ## Leakage-safe forecasting
# Features observed at date **t** are paired with the **next trading day's Close**.
# The target is shifted before the chronological split so same-day Close-derived
# indicators cannot leak the regression target.
#
# ## Artifact safety
# Feature DataFrames are preserved through Random Forest fitting so serialized models
# retain the exact feature names and order required for safe later inference.
#
# ## Overfitting Prevention
# - **max_depth** limits tree depth
# - **min_samples_split** prevents leaves from fitting to single data points
# - **TimeSeriesSplit** cross-validation avoids look-ahead bias during tuning

# %%
import sys; sys.path.insert(0, '..')
import warnings; warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from src.data_loader import (
    fetch_stock_data, prepare_forecast_data
)
from src.backtesting import (
    next_day_direction_signals, next_open_long_flat_returns
)
from src.sentiment_analyzer import add_sentiment_to_df
from src.model_trainer import (
    train_random_forest_regressor,
    train_random_forest_classifier
)
from src.evaluator import (
    regression_metrics, classification_metrics,
    plot_predictions, plot_feature_importance,
    plot_confusion_matrix, sharpe_ratio, max_drawdown_from_returns
)

# %matplotlib inline
plt.style.use('seaborn-v0_8-darkgrid')
print('Setup complete')
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1790017711.032312   43701 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1790017711.032965   43701 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1790017712.049517   43701 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1790017712.049906   43701 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# ...

# %%
# ── Config ────────────────────────────────────────────────────────────────────
TICKER          = 'AAPL'
START           = '2015-01-01'
END             = '2024-12-31'
TRAIN_RATIO     = 0.80
COMMISSION_RATE = 0.001   # 0.1% per position change

FEATURE_COLS = [
    'Open', 'High', 'Low', 'Volume',
    'SMA_10', 'SMA_20', 'SMA_50',
    'RSI_14', 'RSI_7', 'MACD', 'MACD_Signal', 'MACD_Hist',
    'BB_Width', 'ATR_14', 'Vol_Change', 'OBV',
    'Log_Return', 'Pct_Change', 'Sentiment',
    'Close_Lag_1', 'Close_Lag_2', 'Close_Lag_3',
    'Close_Lag_5', 'Close_Lag_10',
]

# %%
# ── 1. Load & Build Leakage-Safe Forecast Samples ─────────────────────────────
df = fetch_stock_data(TICKER, START, END)
df = add_sentiment_to_df(df, TICKER, START, END)

feature_cols = [c for c in FEATURE_COLS if c in df.columns]

# Each feature row at t predicts Close at t+1.
X, y, target_dates = prepare_forecast_data(
    df, feature_cols, target_col='Close', horizon=1
)

split = int(len(X) * TRAIN_RATIO)
# Keep DataFrames here so sklearn persists feature_names_in_ in saved models.
X_train = X.iloc[:split].copy()
X_test  = X.iloc[split:].copy()
y_train = y.iloc[:split].to_numpy()
y_test  = y.iloc[split:].to_numpy()
test_dates = target_dates[split:]
target_open_test = df.loc[test_dates, 'Open'].to_numpy(dtype=float)

# Current close is known at feature time t and is used to define next-day direction.
current_close = df['Close'].iloc[:-1].to_numpy()
current_close_train = current_close[:split]
current_close_test  = current_close[split:]

y_train_dir = (y_train > current_close_train).astype(int)
y_test_dir  = (y_test > current_close_test).astype(int)

print(f'Train samples: {len(X_train)} | Test samples: {len(X_test)}')
print(f'Features at {X.index[0].date()} predict target at {target_dates[0].date()}')
# Out:
# [DataLoader] Fetching AAPL from 2015-01-01 to 2024-12-31 ...
# [DataLoader] Raw shape: (2515, 5)
# [ADF] Close (raw): stat=0.8448, p=0.9923 → NON-STATIONARY
# [ADF] Close (1st diff): stat=-16.1787, p=0.0 → STATIONARY
# [DataLoader] Shape after feature engineering & dropna: (2466, 31)
# [Sentiment] NEWS_API_KEY not set – returning empty list.
# [Sentiment] No headline data – using neutral sentiment fallback.
# Train samples: 1972 | Test samples: 493
# Features at 2015-03-16 predict target at 2015-03-17

# %%
# ── 2a. Regression RF: predict next-day Close ─────────────────────────────────
# tune=True runs GridSearchCV with TimeSeriesSplit (takes a few minutes)
rf_reg = train_random_forest_regressor(
    X_train, y_train,
    tune=True,
    save_path='../results/rf_regressor.pkl'
)

y_pred_reg = rf_reg.predict(X_test)
metrics_reg = regression_metrics(y_test, y_pred_reg, 'RF Regressor')
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [RF] Best params: {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}
# [RF] Model saved → ../results/rf_regressor.pkl
#
# ── RF Regressor Regression Metrics ──────────────────
#   MAE     : 20.5708
#   MSE     : 909.1747
#   RMSE    : 30.1525
#   MAPE%   : 9.6240

# %%
# ── 2b. Classification RF: predict next-day direction ────────────────────────
rf_clf = train_random_forest_classifier(
    X_train, y_train_dir,
    tune=False,
    save_path='../results/rf_classifier.pkl'
)

y_pred_clf = rf_clf.predict(X_test)
metrics_clf = classification_metrics(y_test_dir, y_pred_clf, 'RF Classifier')
# Out:
# [RF-Clf] Model saved → ../results/rf_classifier.pkl
#
# ── RF Classifier Classification Metrics ──────────────
#               precision    recall  f1-score   support
#
#         Down       0.44      0.89      0.59       216
#           Up       0.54      0.10      0.17       277
#
#     accuracy                           0.45       493
#    macro avg       0.49      0.50      0.38       493
# weighted avg       0.49      0.45      0.35       493

# %%
# ── 3. Prediction Plot (Regression) ───────────────────────────────────────────
plot_predictions(y_test, y_pred_reg, label='RF Regressor', dates=test_dates)
# Out:
# [Evaluator] Saved → /agent/repos/stock-price-predictor/notebooks/../src/../results/rf_regressor_predictions.png

# %%
# ── 4. Feature Importance ─────────────────────────────────────────────────────
plot_feature_importance(rf_reg, feature_cols, top_n=15)
# Out:
# [Evaluator] Saved → /agent/repos/stock-price-predictor/notebooks/../src/../results/rf_feature_importance.png

# %%
# ── 5. Confusion Matrix (Classifier) ─────────────────────────────────────────
plot_confusion_matrix(y_test_dir, y_pred_clf, 'RF Classifier')
# Out:
# [Evaluator] Saved → /agent/repos/stock-price-predictor/notebooks/../src/../results/rf_confusion_matrix.png

# %%
# ── 6. Finance Metrics ────────────────────────────────────────────────────────
# Signals are known at feature-bar close; Backtrader fills changes next open.
signals = next_day_direction_signals(y_pred_reg, current_close_test)
strat_rets = next_open_long_flat_returns(
    signals, target_open_test, y_test, commission_rate=COMMISSION_RATE
)

print('\n── RF Strategy Finance Metrics ─────────────')
sr  = sharpe_ratio(strat_rets)
mdd = max_drawdown_from_returns(strat_rets)
# Out:
# ── RF Strategy Finance Metrics ─────────────
#   Sharpe Ratio: 0.8923
#   Max Drawdown: -4.80%

# %%
# ── 7. Save metrics ───────────────────────────────────────────────────────────
import json, os
combined = {**metrics_reg, **metrics_clf,
            'Sharpe': round(sr, 4), 'MaxDrawdown': round(mdd, 4)}
with open('../results/rf_metrics.json', 'w') as f:
    json.dump(combined, f, indent=2)
print('Saved → ../results/rf_metrics.json')
# Out:
# Saved → ../results/rf_metrics.json
